# %% [markdown]
# # Setup and Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# # Import DataSet

# %%
#Datasets in seaborn
print(sns.get_dataset_names())
# Out:
# C:\Users\Abdul Basit\Anaconda3\lib\site-packages\seaborn\utils.py:384: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 384 of the file C:\Users\Abdul Basit\Anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'taxis', 'tips', 'titanic']

# %%
# Load car crashes data set
crash_df= sns.load_dataset('car_crashes')
crash_df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %% [markdown]
# # Distribition Plots

# %% [markdown]
# # Distribution Plot

# %%
# Distribution tells univarient distribution
# Provide distribution for one variable
# Shorthand for details (shift and tab)

# %%
sns.distplot(crash_df['not_distracted'])

# %%
# Line is kernel distribution estimation
# we can remove line by kde= false

# %%
sns.distplot(crash_df['not_distracted'], kde=False)

# %%
# Set Number of bins
sns.distplot(crash_df['not_distracted'], kde=False, bins=25)

# %% [markdown]
# # Joint Plot

# %%
# Draw a plot of two variables with bivariate and univariate graphs.

# %%
sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='reg')

# %%
sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='kde')

# %%
sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='hex')

# %% [markdown]
# # KDE Plot

# %%
sns.kdeplot(crash_df['alcohol'])

# %% [markdown]
# # Pair Plots

# %%
#Pairplot provide relationship between all numerical value of data

# %%
sns.pairplot(crash_df)

# %%
tips_df= sns.load_dataset('tips')
tips_df.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# plot with respect to categorical data like sex, we use hue
# palette is styling
sns.pairplot(tips_df, hue='sex', palette='Blues')

# %% [markdown]
# # Rug Plot

# %%
# It provide density of values
sns.rugplot(tips_df['tip'])

# %% [markdown]
# # STYLING

# %%
sns.set_style('white')

plt.figure(figsize=(8,4))

sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='reg')

# %%
sns.set_style('darkgrid')

plt.figure(figsize=(8,4))

sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='reg')

# %%
sns.set_style('whitegrid')

plt.figure(figsize=(8,4))

sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='reg')

# %%
sns.set_style('dark')

plt.figure(figsize=(8,4))

sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='reg')

# %%
sns.set_style('ticks')

plt.figure(figsize=(8,4))

sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='reg')

# %%
sns.set_style('white')

plt.figure(figsize=(8,4))

sns.set_context('paper', font_scale=1.4)

sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='reg')

# %%
sns.set_style('white')

plt.figure(figsize=(8,4))

sns.set_context('talk', font_scale=1.4)

sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='reg')

# %%
sns.set_style('white')

plt.figure(figsize=(8,4))

sns.set_context('poster', font_scale=1.4)

sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='reg')
# Out:
# C:\Users\Abdul Basit\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1742: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   f.tight_layout()

# %%
sns.set_style('white')

plt.figure(figsize=(8,4))

sns.set_context('paper', font_scale=1.6)

sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='reg')

# %%
sns.set_style('white')

plt.figure(figsize=(8,4))

sns.set_context('paper', font_scale=1.4)

sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='reg')

# If you want to remove left/ right graph lines
sns.despine(left=True)

# %%
sns.set_style('white')

plt.figure(figsize=(8,4))

sns.set_context('paper', font_scale=1.4)

sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='reg')

# If you want to remove left/ right, or bottom graph lines
sns.despine(left=True, bottom=True)

# %% [markdown]
# # CATEGORICAL PLOTS

# %% [markdown]
# # Bar Plot

# %%
# Estimator is mean at default
sns.barplot(x='sex', y='total_bill', data=tips_df)

# %%
sns.barplot(x='sex', y='total_bill', data=tips_df, estimator=np.median)

# %%
sns.barplot(x='sex', y='total_bill', data=tips_df, estimator=np.std)

# %%
sns.barplot(x='sex', y='total_bill', data=tips_df, estimator=np.cov)

# %% [markdown]
# # Count Plot

# %%
# It tell actua number of feature
sns.countplot(x='sex', data=tips_df)

# %% [markdown]
# # Box Plot

# %%
sns.boxplot(x='day',y='total_bill', data=tips_df, hue='sex')

# %%
# Set location of legend
sns.boxplot(x='day',y='total_bill', data=tips_df, hue='sex')
plt.legend(loc=0)

# %% [markdown]
# # Violin Plot

# %%
# It is a combination of box and kde plot

# %%
sns.violinplot(x='day',y='total_bill', data=tips_df, hue='sex')

# %%
sns.violinplot(x='day',y='total_bill', data=tips_df, hue='sex', split=True)

# %% [markdown]
# # Strip Plot

# %%
plt.figure(figsize=(8,5))

sns.stripplot(x='day', y='total_bill', data= tips_df)

# %%
# jitter
plt.figure(figsize=(8,5))

sns.stripplot(x='day', y='total_bill', data= tips_df, jitter=True)

# %%
# Between two categories like male & female
plt.figure(figsize=(8,5))

sns.stripplot(x='day', y='total_bill', data= tips_df, jitter=True, hue='sex')

# %%
# two separate male and female,we use dodge
plt.figure(figsize=(8,5))

sns.stripplot(x='day', y='total_bill', data= tips_df, jitter=True, hue='sex', dodge=True)

# %% [markdown]
# # Swarm Plot

# %%
sns.swarmplot(x='day', y='total_bill', data=tips_df)

# %%
# On violin plot, we draw swarm plot, color is white so we can see swarm
sns.violinplot(x='day', y='total_bill', data=tips_df)
sns.swarmplot(x='day', y='total_bill', data=tips_df, color='white')

# %% [markdown]
# # Palettes

# %%
# Change the color of striplot
plt.figure(figsize=(8,6))
sns.set_style('white')
sns.set_context('talk')
sns.stripplot(x='day', y='total_bill', data=tips_df, hue='sex', palette='afmhot')

# %%
# Change the color of striplot
plt.figure(figsize=(8,6))
sns.set_style('white')
sns.set_context('talk')
sns.stripplot(x='day', y='total_bill', data=tips_df, hue='sex', palette='afmhot')

# Legend reposition: upper right=1, upper left=2, lower left=3, lower right=4
plt.legend(loc=3)

# %% [markdown]
# # MATRIX PLOTS

# %% [markdown]
# # Heatmap

# %%
# first extract corr() from all data
crash_mx=crash_df.corr()
print(crash_mx)
# Out:
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# speeding          -0.077675   -0.065928
# alcohol           -0.170612   -0.112547
# not_distracted    -0.174856   -0.075970
# no_previous       -0.156895   -0.006359
# ins_premium        1.000000    0.623116
# ins_losses         0.623116    1.000000

# %%
plt.figure(figsize=(8,6))
sns.set_context('paper', font_scale=1.4)

# we here use crash_mx
# annot for numeric values
# cmap, color map, there are many, see docs for more

sns.heatmap(crash_mx, annot=True, cmap='Blues')

# %%
# Method no2 with pivot table
# new flights data

flights= sns.load_dataset('flights')
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flights= flights.pivot_table(index='month', columns='year', values='passengers')
sns.heatmap(flights, cmap='Blues')

# %%
# Lines for clear visibilty
sns.heatmap(flights, cmap='Blues', linecolor='white', linewidth=1)

# %% [markdown]
# # Cluster Map

# %%
# we use iris data here
iris= sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# first pop target data
species= iris.pop('species')
sns.clustermap(iris)

# %%
# Apply cluster map on flights data
sns.clustermap(flights, cmap='Blues', standard_scale=1)

# %% [markdown]
# # Pir Grid

# %%
# pair grid is a extension of pair plot but in this plot we can limit what type of graphs we want
# we want only scatter 
iris= sns.load_dataset('iris')
iris_g=sns.PairGrid(iris, hue='species')
iris_g.map(plt.scatter)

# %%
# we want histograms on diagonal and scatter on off diagonal
iris= sns.load_dataset('iris')
iris_g=sns.PairGrid(iris, hue='species')
iris_g.map_diag(plt.hist)
iris_g.map_offdiag(plt.scatter)

# %%
# we want scatter on upper and kde on lower
iris= sns.load_dataset('iris')
iris_g=sns.PairGrid(iris, hue='species')
iris_g.map_diag(plt.hist)

iris_g.map_upper(plt.scatter)
iris_g.map_lower(sns.kdeplot)

# %%
# Another Method
iris= sns.load_dataset('iris')

iris_g= sns.PairGrid(iris, hue='species',
                     x_vars=['sepal_length', 'sepal_width'],
                    y_vars=['petal_length', 'petal_width'])
iris_g.map(plt.scatter)

iris_g.add_legend()

# %% [markdown]
# # Facet Grid

# %%
tips_df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
tips_fg= sns.FacetGrid(tips_df, col= 'time', row='smoker')
tips_fg.map(plt.hist, 'total_bill', bins=8)

# %%
#Scatter
tips_fg= sns.FacetGrid(tips_df, col= 'time', row='smoker')
tips_fg.map(plt.scatter, 'total_bill', "tip")

# %%
# col_order is to arrange what to plot first
tips_fg= sns.FacetGrid(tips_df, col='time', hue='smoker', height=4, aspect=1.3,
                      col_order=['Dinner', 'Lunch'], palette='Set1')
tips_fg.map(plt.scatter, 'total_bill','tip', edgecolor='w')

# %%
# s= size of market
# ^ for upper marker, v for lower marker

kws= dict(s=50, linewidth=0.5, edgecolor='w')
tips_fg= sns.FacetGrid(tips_df, col='sex', hue= 'smoker', height=4, aspect=1.3,
                      hue_order=['Yes', 'No'],
                      hue_kws=dict(marker=['^','v']))
tips_fg.map(plt.scatter, 'total_bill', 'tip', **kws)

# %%
# Now with different data
att_df= sns.load_dataset('attention')
att_df.head(2)
# Out:
#    Unnamed: 0  subject attention  solutions  score
# 0           0        1   divided          1    2.0
# 1           1        2   divided          1    3.0

# %%
att_fg=sns.FacetGrid(att_df, col= 'subject', col_wrap=5, height=1.5)
att_fg.map(plt.plot, 'solutions', 'score', marker='.')

# %% [markdown]
# # Regression Plot

# %%
tips_df.head(4)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2

# %%
plt.figure(figsize=(8,6))
sns.set_context('paper', font_scale=1.4)
sns.lmplot(x='total_bill', y='tip', hue='sex', data=tips_df, markers=['o','^'],
          scatter_kws={'s':100, 'linewidth':0.5, 'edgecolor':'w'})

# %%
sns.lmplot(x='total_bill', y='tip', col='sex', row='time', data=tips_df)

# %%
sns.set_context('paper', font_scale=1.4)
sns.lmplot(x='total_bill', y='tip', col='sex', row='time', data=tips_df,
          height=8, aspect=0.6)
